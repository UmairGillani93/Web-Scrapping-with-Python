# %%
import pandas as pd 

df = pd.read_csv('IT_jobs_Islamabad.csv')

pd.set_option('display.max_rows', 200)

df
# Out:
#                                                  Title    Location  \
# 0                                    Software Engineer  Rawalpindi
# 1                    Software Engineer/.Net Developers   Islamabad
# 2                                    RESIDENT ENGINEER   Islamabad
# 3    Intern - Junior Software Engineer / .Net Devel...   Islamabad
# 4                             Computer Vision Engineer   Islamabad
# 5    Transformer Service Engineer, Islamabad; Pakistan   Islamabad
# 6                                    Software Engineer   Islamabad
# 7                                    Software Engineer  Rawalpindi
# 8                                    Software Engineer   Islamabad
# 9                                    Software Engineer   Islamabad
# 10                   Software Engineer/.Net Developers   Islamabad
# 11                Software Engineer (.NET Development)   Islamabad
# 12   Sr. Software Engineer (.Net / Angular) - Islam...   Islamabad
# ...

# %%
df['Company']
# Out:
# 0                                           MTBC
# 1                              Dera IT Solutions
# 2                              Interactive Group
# 3                                         Noorax
# 4                                       PackageX
# 5                                            ABB
# 6                                Bentley Systems
# 7                             Kamal Laboratories
# 8           MFSYS Software & Systems (Pvt.) Ltd.
# 9                                       Teradata
# 10                             Dera IT Solutions
# 11     ALTUMED (Cube Healthcare Systems Pvt Ltd)
# 12                               Ark IT Services
# 13                            Kamal Laboratories
# 14                                      PackageX
# 15                                   TauMobility
# 16                             Interactive Group
# 17                                          MSPL
# 18             Evolved Systems (Private) Limited
# ...

# %%
df['Location'].value_counts()
# Out:
# Islamabad     178
# Rawalpindi     22
# Name: Location, dtype: int64

# %%
df['Location'].value_counts()
# Out:
# Islamabad     178
# Rawalpindi     22
# Name: Location, dtype: int64

# %%
import pandas as pd 

df1 = pd.read_csv('glassdoor.csv')

df1
# Out:
#     Unnamed: 0                          Teradata
# 0      Website                  www.teradata.com
# 1  Headquaters                     San Diego, CA
# 2         Size                  10000+ employees
# 3      Founded                              1979
# 4         Type           Company - Public (TDC)
# 5     Industry      Computer Hardware & Software
# 6      Revenue   $2 to $5 billion (USD) per year
# 7  Competitors             Cloudera, IBM, Oracle
