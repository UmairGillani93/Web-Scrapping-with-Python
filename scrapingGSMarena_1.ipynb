# %%
from bs4 import BeautifulSoup
from requests import get

# %%
url = 'https://www.gsmarena.com/apple_iphone_x-reviews-8858.php'

page = get(url)

print(page.text[:500])
# Out:
# <!doctype html>
# <html xmlns="http://www.w3.org/1999/xhtml" xml:lang="en-US" lang="en-US">
# <head>
# <title>Apple iPhone X - User opinions and reviews</title>
#
#
#
#
# <script data-cfasync="false" type="text/javascript">(function(w, d) { var s = d.createElement('script'); s.src = '//delivery.adrecover.com/16425/adRecover.js?ts=1527752433225'; s.type = 'text/javascript'; s.async = true; (d.getElementsByTagName('head')[0] || d.getElementsByTagName('body')[0]).appendChild(s); })(window, document);</

# %%
soup = BeautifulSoup(page.text, 'html.parser')

print(soup.title)
# Out:
# <title>Apple iPhone X - User opinions and reviews</title>

# %%
all_opinions = soup.find_all('p', {'class': 'uopin'})

# %%
type(all_opinions)
# Out:
# bs4.element.ResultSet

# %%
print(type(all_opinions))
print(len(all_opinions))
# Out:
# <class 'bs4.element.ResultSet'>
# 20

# %%
first_opinion = all_opinions[0]

# %%
first_opinion.text
# Out:
# 'The first revolutionary iPhone in the X series. It is still holding up great. Can easily take me for the next 2 years at least. '

# %%
type(first_opinion.text)
# Out:
# str

# %%
second_opinion = all_opinions[1].text.strip()

# %%
second_opinion
# Out:
# 'How come no 12.4 beta iOS update for iPhone X??'

# %%
third_opinion = all_opinions[2].text.strip()

# %%
third_opinion
# Out:
# 'Azeezabdull, 06 Jun 2019Hi. I got a issue after updating iOS 12.3 example: battery draining faster signal drops phone ... moreSame with mine. Over a period of 1 month mine dropped 3%, I mean the battery health.'

# %%
last_opinion = all_opinions[-1].text.strip()

# %%
print(all_opinions[:5])
# Out:
# [<p class="uopin">The first revolutionary iPhone in the X series. It is still holding up great. Can easily take me for the next 2 years at least. </p>, <p class="uopin">How come no 12.4 beta iOS update for iPhone X?? </p>, <p class="uopin"><a class="uinreply" href="#6044901"><i class="head-icon icon-reply"></i>Azeezabdull, 06 Jun 2019</a><span class="uinreply-msg">Hi. I got a issue after updating iOS 12.3 example: battery draining faster signal drops phone ... <a href="#6044901">more</a></span>Same with mine. Over a period of 1 month mine dropped 3%, I mean the battery health.</p>, <p class="uopin">Is there any issue after 12.3.1??? </p>, <p class="uopin"><a class="uinreply" href="#6044901"><i class="head-icon icon-reply"></i>Azeezabdull, 06 Jun 2019</a><span class="uinreply-msg">Hi. I got a issue after updating iOS 12.3 example: battery draining faster signal drops phone ... <a href="#6044901">more</a></span>Try ios 12.3.1</p>]

# %%
comment_dict = {}
keys = []
values = []

for item in all_opinions:
    item = item.text.strip()
    values.append(item)
    
for value in all_opinions:
    if 'Anonymous' in value:
        values.append(value.text[:10].strip())

# %%
values
# Out:
# ['The first revolutionary iPhone in the X series. It is still holding up great. Can easily take me for the next 2 years at least.',
#  'How come no 12.4 beta iOS update for iPhone X??',
#  'Azeezabdull, 06 Jun 2019Hi. I got a issue after updating iOS 12.3 example: battery draining faster signal drops phone ... moreSame with mine. Over a period of 1 month mine dropped 3%, I mean the battery health.',
#  'Is there any issue after 12.3.1???',
#  'Azeezabdull, 06 Jun 2019Hi. I got a issue after updating iOS 12.3 example: battery draining faster signal drops phone ... moreTry ios 12.3.1',
#  'Anonymous, 05 Jun 2019hi! got the same issue after updating 12.3. may i know what did you do abiut that? Hi. I got a issue after updating iOS 12.3 example: battery draining faster signal drops phone getting hot is there any solution for this problem.',
# ...

# %%
len(values)
# Out:
# 20

# %%
for value in values:
    value.strip('/')

# %%
values[6]
# Out:
# 'Anonymous, 05 Jun 2019hi! got the same issue after updating 12.3. may i know what did you do abiut that? Hi. After updating 12.3update lots of issue example  battery draining faster  \r\nPhone getting hot network problem`s do you have any idea with this'

# %%
values
# Out:
# ['The first revolutionary iPhone in the X series. It is still holding up great. Can easily take me for the next 2 years at least.',
#  'How come no 12.4 beta iOS update for iPhone X??',
#  'Azeezabdull, 06 Jun 2019Hi. I got a issue after updating iOS 12.3 example: battery draining faster signal drops phone ... moreSame with mine. Over a period of 1 month mine dropped 3%, I mean the battery health.',
#  'Is there any issue after 12.3.1???',
#  'Azeezabdull, 06 Jun 2019Hi. I got a issue after updating iOS 12.3 example: battery draining faster signal drops phone ... moreTry ios 12.3.1',
#  'Anonymous, 05 Jun 2019hi! got the same issue after updating 12.3. may i know what did you do abiut that? Hi. I got a issue after updating iOS 12.3 example: battery draining faster signal drops phone getting hot is there any solution for this problem.',
# ...

# %%
names = soup.find_all('li', {'class': 'uname2'})

# %%
first_name = names[0]

# %%
first_name.text.strip()
# Out:
# 'Pat Ph'

# %%
names[1].text.strip()
# Out:
# 'ATP7B'

# %%
for name in names:
    name = name.text.strip()
    keys.append(name)
    
print(keys)
# Out:
# ['Pat Ph', 'ATP7B', 'kingpin', 'Less', 'Azeez', 'Anonymous', 'Anonymous', 'Anonymous', 'Less', 'Mohsin', 'Less', 'Less', 'DJ', 'sk', 'Less', 'sumit', 'Less']

# %%
len(keys)
# Out:
# 17

# %%
locations = soup.find_all('li', {'class': 'ulocation'})

# %%
first_location = locations[0]

# %%
first_location
# Out:
# <li class="ulocation"><i class="head-icon icon-location"></i><span title="Encoded anonymized location">ITL</span></li>

# %%
comment_dict = dict(zip(keys,values))

# %%
comment_dict['Azeez']
# Out:
# 'Azeezabdull, 06 Jun 2019Hi. I got a issue after updating iOS 12.3 example: battery draining faster signal drops phone ... moreTry ios 12.3.1'

# %%
comment_dict['Mohsin']
# Out:
# "I think this mobile will be good for business man and I hope if it 'd my mobile phone"

# %%
import pandas as pd

# %%
comments_df = pd.DataFrame.from_dict(data = comment_dict, orient = 'index', columns = ['Comments'])

# %%
comments_df
# Out:
#                                                     Comments
# Pat Ph     The first revolutionary iPhone in the X series...
# ATP7B        How come no 12.4 beta iOS update for iPhone X??
# kingpin    Azeezabdull, 06 Jun 2019Hi. I got a issue afte...
# Less       sumit, 22 May 2019siri and search not working ...
# Azeez      Azeezabdull, 06 Jun 2019Hi. I got a issue afte...
# Anonymous  Mohsin, 01 Jun 2019guys after updating to late...
# Mohsin     I think this mobile will be good for business ...
# DJ         DJ, 24 May 2019I Love This New Huawei............
# sk         sk, 24 May 2019Huawei is the best....its takin...
# sumit      Huawei is the best....its taking over the mobi...

# %%
import os
import nltk
import nltk.corpus

# %%
print(os.listdir(nltk.data.find('corpora')))
# Out:
# ['chat80.zip', 'biocreative_ppi', 'wordnet', 'conll2002.zip', 'europarl_raw', 'comparative_sentences.zip', 'dependency_treebank', 'city_database.zip', 'dolch', 'treebank', 'floresta', 'chat80', 'framenet_v15.zip', 'conll2002', 'cess_esp.zip', 'conll2000', 'dolch.zip', 'europarl_raw.zip', 'wordnet.zip', 'brown_tei', 'conll2007.zip', 'alpino', 'alpino.zip', 'floresta.zip', 'city_database', 'cess_esp', 'cess_cat', 'brown.zip', 'abc.zip', 'crubadan', 'cmudict', 'words', 'dependency_treebank.zip', 'treebank.zip', 'cmudict.zip', 'cess_cat.zip', 'words.zip', 'abc', 'brown', 'brown_tei.zip', 'comtrans.zip', 'crubadan.zip', 'conll2000.zip', 'biocreative_ppi.zip', 'comparative_sentences']

# %%
para_ = ''

for value in values:
    para_ += value + ' '
    
para_
# Out:
# 'The first revolutionary iPhone in the X series. It is still holding up great. Can easily take me for the next 2 years at least. How come no 12.4 beta iOS update for iPhone X?? Azeezabdull, 06 Jun 2019Hi. I got a issue after updating iOS 12.3 example: battery draining faster signal drops phone ... moreSame with mine. Over a period of 1 month mine dropped 3%, I mean the battery health. Is there any issue after 12.3.1??? Azeezabdull, 06 Jun 2019Hi. I got a issue after updating iOS 12.3 example: battery draining faster signal drops phone ... moreTry ios 12.3.1 Anonymous, 05 Jun 2019hi! got the same issue after updating 12.3. may i know what did you do abiut that? Hi. I got a issue after updating iOS 12.3 example: battery draining faster signal drops phone getting hot is there any solution for this problem. Anonymous, 05 Jun 2019hi! got the same issue after updating 12.3. may i know what did you do abiut that? Hi. After updating 12.3update lots of issue example  battery draining faster  
# ...

# %%
from nltk.tokenize import word_tokenize

# %%
para_tokens = word_tokenize(para_)

# %%
para_tokens
# Out:
# ['The',
#  'first',
#  'revolutionary',
#  'iPhone',
#  'in',
#  'the',
#  'X',
#  'series',
#  '.',
#  'It',
#  'is',
#  'still',
#  'holding',
#  'up',
#  'great',
#  '.',
#  'Can',
#  'easily',
#  'take',
#  'me',
#  'for',
#  'the',
#  'next',
#  '2',
#  'years',
#  'at',
#  'least',
#  '.',
#  'How',
#  'come',
#  'no',
#  '12.4',
#  'beta',
#  'iOS',
#  'update',
#  'for',
#  'iPhone',
#  'X',
#  '?',
#  '?',
#  'Azeezabdull',
#  ',',
#  '06',
#  'Jun',
#  '2019Hi',
#  '.',
#  'I',
#  'got',
#  'a',
#  'issue',
#  'after',
#  'updating',
#  'iOS',
#  '12.3',
#  'example',
#  ':',
#  'battery',
#  'draining',
#  'faster',
#  'signal',
#  'drops',
#  'phone',
#  '...',
#  'moreSame',
#  'with',
#  'mine',
#  '.',
#  'Over',
#  'a',
#  'period',
#  'of',
#  '1',
#  'month',
#  'mine',
#  'dropped',
#  '3',
#  '%',
#  ',',
#  'I',
#  'mean',
#  'the',
#  'battery',
#  'health',
#  '.',
#  'Is',
#  'there',
#  'any',
#  'issue',
#  'after',
#  '12.3.1',
#  '?',
#  '?',
#  '?',
# ...

# %%
print(len(para_tokens))
print(type(para_tokens))
# Out:
# 866
# <class 'list'>

# %%
from nltk.probability import FreqDist
fdist = FreqDist()

# %%
for word in para_tokens:
    fdist[word.lower()] += 1
    
fdist
# Out:
# FreqDist({'.': 31, ',': 26, '...': 26, 'and': 21, 'the': 20, 'is': 18, 'i': 17, 'after': 13, 'updating': 10, 'to': 10, ...})

# %%
fdist_topten = fdist.most_common(10)

# %%
fdist_topten
# Out:
# [('.', 31),
#  (',', 26),
#  ('...', 26),
#  ('and', 21),
#  ('the', 20),
#  ('is', 18),
#  ('i', 17),
#  ('after', 13),
#  ('updating', 10),
#  ('to', 10)]

# %%
from nltk.util import bigrams, trigrams, ngrams

# %%
quotes_tokens = word_tokenize(para_)
quotes_tokens
# Out:
# ['The',
#  'first',
#  'revolutionary',
#  'iPhone',
#  'in',
#  'the',
#  'X',
#  'series',
#  '.',
#  'It',
#  'is',
#  'still',
#  'holding',
#  'up',
#  'great',
#  '.',
#  'Can',
#  'easily',
#  'take',
#  'me',
#  'for',
#  'the',
#  'next',
#  '2',
#  'years',
#  'at',
#  'least',
#  '.',
#  'How',
#  'come',
#  'no',
#  '12.4',
#  'beta',
#  'iOS',
#  'update',
#  'for',
#  'iPhone',
#  'X',
#  '?',
#  '?',
#  'Azeezabdull',
#  ',',
#  '06',
#  'Jun',
#  '2019Hi',
#  '.',
#  'I',
#  'got',
#  'a',
#  'issue',
#  'after',
#  'updating',
#  'iOS',
#  '12.3',
#  'example',
#  ':',
#  'battery',
#  'draining',
#  'faster',
#  'signal',
#  'drops',
#  'phone',
#  '...',
#  'moreSame',
#  'with',
#  'mine',
#  '.',
#  'Over',
#  'a',
#  'period',
#  'of',
#  '1',
#  'month',
#  'mine',
#  'dropped',
#  '3',
#  '%',
#  ',',
#  'I',
#  'mean',
#  'the',
#  'battery',
#  'health',
#  '.',
#  'Is',
#  'there',
#  'any',
#  'issue',
#  'after',
#  '12.3.1',
#  '?',
#  '?',
#  '?',
# ...

# %%
quotes_bigrams = list(nltk.bigrams(quotes_tokens))
quotes_trigrams = list(nltk.trigrams(quotes_tokens))

# %%
quotes_bigrams
# Out:
# [('The', 'first'),
#  ('first', 'revolutionary'),
#  ('revolutionary', 'iPhone'),
#  ('iPhone', 'in'),
#  ('in', 'the'),
#  ('the', 'X'),
#  ('X', 'series'),
#  ('series', '.'),
#  ('.', 'It'),
#  ('It', 'is'),
#  ('is', 'still'),
#  ('still', 'holding'),
#  ('holding', 'up'),
#  ('up', 'great'),
#  ('great', '.'),
#  ('.', 'Can'),
#  ('Can', 'easily'),
#  ('easily', 'take'),
#  ('take', 'me'),
#  ('me', 'for'),
#  ('for', 'the'),
#  ('the', 'next'),
#  ('next', '2'),
#  ('2', 'years'),
#  ('years', 'at'),
#  ('at', 'least'),
#  ('least', '.'),
#  ('.', 'How'),
#  ('How', 'come'),
#  ('come', 'no'),
#  ('no', '12.4'),
#  ('12.4', 'beta'),
#  ('beta', 'iOS'),
#  ('iOS', 'update'),
#  ('update', 'for'),
#  ('for', 'iPhone'),
#  ('iPhone', 'X'),
#  ('X', '?'),
#  ('?', '?'),
#  ('?', 'Azeezabdull'),
#  ('Azeezabdull', ','),
#  (',', '06'),
#  ('06', 'Jun'),
#  ('Jun', '2019Hi'),
#  ('2019Hi', '.'),
#  ('.', 'I'),
#  ('I', 'got'),
#  ('got', 'a'),
#  ('a', 'issue'),
# ...

# %%
quotes_trigrams
# Out:
# [('The', 'first', 'revolutionary'),
#  ('first', 'revolutionary', 'iPhone'),
#  ('revolutionary', 'iPhone', 'in'),
#  ('iPhone', 'in', 'the'),
#  ('in', 'the', 'X'),
#  ('the', 'X', 'series'),
#  ('X', 'series', '.'),
#  ('series', '.', 'It'),
#  ('.', 'It', 'is'),
#  ('It', 'is', 'still'),
#  ('is', 'still', 'holding'),
#  ('still', 'holding', 'up'),
#  ('holding', 'up', 'great'),
#  ('up', 'great', '.'),
#  ('great', '.', 'Can'),
#  ('.', 'Can', 'easily'),
#  ('Can', 'easily', 'take'),
#  ('easily', 'take', 'me'),
#  ('take', 'me', 'for'),
#  ('me', 'for', 'the'),
#  ('for', 'the', 'next'),
#  ('the', 'next', '2'),
#  ('next', '2', 'years'),
#  ('2', 'years', 'at'),
#  ('years', 'at', 'least'),
#  ('at', 'least', '.'),
#  ('least', '.', 'How'),
#  ('.', 'How', 'come'),
#  ('How', 'come', 'no'),
#  ('come', 'no', '12.4'),
#  ('no', '12.4', 'beta'),
#  ('12.4', 'beta', 'iOS'),
#  ('beta', 'iOS', 'update'),
#  ('iOS', 'update', 'for'),
#  ('update', 'for', 'iPhone'),
# ...

# %%
quotes_ngrams = list(nltk.ngrams(quotes_tokens, 5))

# %%
quotes_ngrams
# Out:
# [('The', 'first', 'revolutionary', 'iPhone', 'in'),
#  ('first', 'revolutionary', 'iPhone', 'in', 'the'),
#  ('revolutionary', 'iPhone', 'in', 'the', 'X'),
#  ('iPhone', 'in', 'the', 'X', 'series'),
#  ('in', 'the', 'X', 'series', '.'),
#  ('the', 'X', 'series', '.', 'It'),
#  ('X', 'series', '.', 'It', 'is'),
#  ('series', '.', 'It', 'is', 'still'),
#  ('.', 'It', 'is', 'still', 'holding'),
#  ('It', 'is', 'still', 'holding', 'up'),
#  ('is', 'still', 'holding', 'up', 'great'),
#  ('still', 'holding', 'up', 'great', '.'),
#  ('holding', 'up', 'great', '.', 'Can'),
#  ('up', 'great', '.', 'Can', 'easily'),
#  ('great', '.', 'Can', 'easily', 'take'),
#  ('.', 'Can', 'easily', 'take', 'me'),
#  ('Can', 'easily', 'take', 'me', 'for'),
#  ('easily', 'take', 'me', 'for', 'the'),
#  ('take', 'me', 'for', 'the', 'next'),
#  ('me', 'for', 'the', 'next', '2'),
#  ('for', 'the', 'next', '2', 'years'),
#  ('the', 'next', '2', 'years', 'at'),
#  ('next', '2', 'years', 'at', 'least'),
# ...

# %%
# stemming -> normalize a word into its base / root form

# %%
from nltk.stem import PorterStemmer
pst = PorterStemmer()

pst.stem('having')
# Out:
# 'have'

# %%
pst.stem('gratitude')
# Out:
# 'gratitud'

# %%
pst.stem('exoneration')
# Out:
# 'exoner'

# %%
pst.stem('walking')
# Out:
# 'walk'

# %%
wordlist = ['cooking', 'wonderful', 'swimming', 'notorious']

for word in wordlist:
    stemmed_word = pst.stem(word)
    print(word + ' : ' + stemmed_word)
    print('\n')
# Out:
# cooking : cook
#
#
# wonderful : wonder
#
#
# swimming : swim
#
#
# notorious : notori

# %%
wordlist1 = ['went', 'going', 'gone']

for word in wordlist1:
    stemmed_word = pst.stem(word)
    print(word + ' : ' + stemmed_word)
    print('\n')
# Out:
# went : went
#
#
# going : go
#
#
# gone : gone

# %%
# lemmatization: takes into consideration the morphological analysis of the word

# %%
from nltk.stem import wordnet
from nltk.stem import WordNetLemmatizer

word_lem = WordNetLemmatizer()

word_lem.lemmatize('corpora')
# Out:
# 'corpus'

# %%
for word in ['go', 'went', 'gone']:
    lemmatize_word = word_lem.lemmatize(word)
    print(word + ' | ' + lemmatize_word)
    print('\n')
# Out:
# go | go
#
#
# went | went
#
#
# gone | gone

# %%
from nltk.corpus import stopwords

# %%
#stopwords.word('english')

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/umairshah/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
print(stopwords.words('english')) # reports back the stopwords in English language
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
len(stopwords.words('english'))
# Out:
# 179

# %%
fdist_topten # reports back the top 10 most accuring words in our corpus
# Out:
# [('.', 31),
#  (',', 26),
#  ('...', 26),
#  ('and', 21),
#  ('the', 20),
#  ('is', 18),
#  ('i', 17),
#  ('after', 13),
#  ('updating', 10),
#  ('to', 10)]

# %%
# Removing the punctuations from corpus
import string

def no_punc(words):
    
    nopunc = [char for char in words if char not in string.punctuation]
    nopunc = ''.join(nopunc)
    
    return nopunc

# %%
document = 'Hey!! how are you doing??'
no_punc(document)
# Out:
# 'Hey how are you doing'

# %%
# applying demo function to original corpus

new_para = no_punc(para_)

# %%
# Out:
# 'The first revolutionary iPhone in the X series It is still holding up great Can easily take me for the next 2 years at least How come no 124 beta iOS update for iPhone X Azeezabdull 06 Jun 2019Hi I got a issue after updating iOS 123 example battery draining faster signal drops phone  moreSame with mine Over a period of 1 month mine dropped 3 I mean the battery health Is there any issue after 1231 Azeezabdull 06 Jun 2019Hi I got a issue after updating iOS 123 example battery draining faster signal drops phone  moreTry ios 1231 Anonymous 05 Jun 2019hi got the same issue after updating 123 may i know what did you do abiut that Hi I got a issue after updating iOS 123 example battery draining faster signal drops phone getting hot is there any solution for this problem Anonymous 05 Jun 2019hi got the same issue after updating 123 may i know what did you do abiut that Hi After updating 123update lots of issue example  battery draining faster  \r\nPhone getting hot network problems do you h
# ...

# %%
# function that checks if there's any stopwords in our corpus

def check_for_stops(corpus):
    
    count = 0
    for word in stopwords.words('english'):
        if word in new_para:
            count += 1
            print(word)
            del word
        
    return count

# %%
new_para[:100]
# Out:
# 'The first revolutionary iPhone in the X series It is still holding up great Can easily take me for t'

# %%
# Parts of Speech Tagging
# every token in corpus corresponds to a POS Tag
# lets's find out

new_para_tokens = word_tokenize(new_para)

# %%
new_para_tokens[:10]
# Out:
# ['The',
#  'first',
#  'revolutionary',
#  'iPhone',
#  'in',
#  'the',
#  'X',
#  'series',
#  'It',
#  'is']

# %%
# reports back the parts of speech tags for all the words in corpus

for token in new_para_tokens:
    pos_tagged_para = (nltk.pos_tag(new_para_tokens))

# %%
len(pos_tagged_para)
# Out:
# 736

# %%
from nltk import ne_chunk

named_entities = ne_chunk(pos_tagged_para)
print(named_entities)
# Out:
# (S
#   The/DT
#   first/JJ
#   revolutionary/JJ
#   iPhone/NN
#   in/IN
#   the/DT
#   X/NNP
#   series/NN
#   It/PRP
#   is/VBZ
#   still/RB
#   holding/VBG
#   up/RP
#   great/JJ
#   Can/MD
#   easily/RB
#   take/VB
#   me/PRP
#   for/IN
#   the/DT
#   next/JJ
#   2/CD
#   years/NNS
#   at/IN
#   least/JJS
#   How/NNP
#   come/JJ
#   no/DT
#   124/JJ
#   beta/NN
#   (ORGANIZATION iOS/NN)
#   update/NN
#   for/IN
#   (ORGANIZATION iPhone/NN X/NNP)
#   Azeezabdull/NNP
#   06/CD
#   Jun/NNP
#   2019Hi/CD
#   I/PRP
#   got/VBD
#   a/DT
#   issue/NN
#   after/IN
#   updating/VBG
#   (ORGANIZATION iOS/JJ)
#   123/CD
#   example/NN
#   battery/NN
#   draining/VBG
#   faster/RBR
#   signal/JJ
#   drops/NNS
#   phone/NN
#   moreSame/NN
#   with/IN
#   mine/NN
#   Over/IN
#   a/DT
#   period/NN
#   of/IN
#   1/CD
#   month/NN
#   mine/NN
#   dropped/VBD
#   3/CD
#   I/PRP
#   mean/VBP
#   the/DT
#   battery/NN
#   health/NN
#   Is/NNP
#   there/RB
#   any/DT
#   issue/NN
#   after/IN
# ...

# %%
# converting corpus of words into word embeddings for our Neural Network classifier interpretations

import gensim
from gensim import models, similarities, corpora

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/umairshah/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
para_[:100]
# Out:
# 'The first revolutionary iPhone in the X series. It is still holding up great. Can easily take me for'

# %%
tok_corpus = word_tokenize(para_)

# %%
model = gensim.models.Word2Vec(tok_corpus)

# %%
model.corpus_count
# Out:
# 866
