# %%
from bs4 import BeautifulSoup
from requests import get

# %%
url = 'https://www.gsmarena.com/huawei_nova_3i-reviews-9632.php'

for num in range(5):
    i = 2
    new_url = url[:-4] + 'p' + str(i) + '.php'
    pages = get(new_url)
    i += 1

print(pages)
# Out:
# <Response [200]>

# %%
new_url
# Out:
# 'https://www.gsmarena.com/huawei_nova_3i-reviews-9632p2.php'

# %%
soup = BeautifulSoup(pages.text, 'html.parser')

# %%
print(soup.title)
# Out:
# <title>Huawei nova 3i - User opinions and reviews - page 2</title>

# %%
# Out:
# '<!DOCTYPE doctype html>\n<html lang="en-US" xml:lang="en-US" xmlns="http://www.w3.org/1999/xhtml">\n <head>\n  <title>\n   Huawei nova 3i - User opinions and reviews - page 2\n  </title>\n  <script data-cfasync="false" type="text/javascript">\n   (function(w, d) { var s = d.createElement(\'script\'); s.src = \'//delivery.adrecover.com/16425/adRecover.js?ts=1527752433225\'; s.type = \'text/javascript\'; s.async = true; (d.getElementsByTagName(\'head\')[0] || d.getElementsByTagName(\'body\')[0]).appendChild(s); })(window, document);\n  </script>\n  <link href="https://cdn.gsmarena.com/vv/assets10/css/gsmarena.css?v=78" rel="stylesheet"/>\n  <script src="//dsh7ky7308k4b.cloudfront.net/publishers/gsmarenacom.min.js" type="text/javascript">\n  </script>\n  <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js">\n  </script>\n  <script>\n   var googletag = googletag || {};\r\n  googletag.cmd = googletag.cmd || [];\n  </script>\n  <script>\n   googletag.cmd.push(functi
# ...
